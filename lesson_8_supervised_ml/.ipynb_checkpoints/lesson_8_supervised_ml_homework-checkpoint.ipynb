# %%
import pandas as pd

# %%
train= pd.read_csv("data/train.csv")
test = pd.read_csv("data/test.csv")
train
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
test.isnull().sum() + train.isnull().sum()
# Out:
# Age             263.0
# Cabin          1014.0
# Embarked          2.0
# Fare              1.0
# Name              0.0
# Parch             0.0
# PassengerId       0.0
# Pclass            0.0
# Sex               0.0
# SibSp             0.0
# Survived          NaN
# Ticket            0.0
# dtype: float64

# %%
from sklearn.model_selection import train_test_split, GridSearchCV
from sklearn.ensemble import RandomForestClassifier, GradientBoostingClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.tree import DecisionTreeClassifier
from sklearn.preprocessing import LabelEncoder
from sklearn.impute import SimpleImputer
from xgboost import XGBClassifier

for col in ['Age', 'Fare']:
    imputer = SimpleImputer(strategy='median')
    train[col] = imputer.fit_transform(train[[col]])
    test[col] = imputer.transform(test[[col]])

train['Embarked'] = train['Embarked'].fillna(train['Embarked'].mode()[0])
test['Embarked'] = test['Embarked'].fillna(train['Embarked'].mode()[0])

for col in ['Sex', 'Embarked']:
    le = LabelEncoder()
    train[col] = le.fit_transform(train[col])
    test[col] = le.transform(test[col])

features = ['Pclass', 'Sex', 'Age', 'SibSp', 'Parch', 'Fare', 'Embarked']
X = train[features]
y = train['Survived']
X_train, X_val, y_train, y_val = train_test_split(X, y, random_state=42)

# %%
test.isnull().sum() + train.isnull().sum()
# Out:
# Age               0.0
# Cabin          1014.0
# Embarked          0.0
# Fare              0.0
# Name              0.0
# Parch             0.0
# PassengerId       0.0
# Pclass            0.0
# Sex               0.0
# SibSp             0.0
# Survived          NaN
# Ticket            0.0
# dtype: float64

# %%
classifiers_grid = {
    'LogisticRegression': (
        LogisticRegression(max_iter=1000),
        {'C': [0.01, 0.1, 1, 10, 100]}
    ),
    'DecisionTree': (
        DecisionTreeClassifier(),
        {'max_depth': [3, 5, 7, 10, None],
         'min_samples_split': [2, 5, 10]}
    ),
    'RandomForest': (
        RandomForestClassifier(),
        {'n_estimators': [50, 100, 200],
         'max_depth': [3, 5, 7, None],
         'min_samples_split': [2, 5]}
    ),
    'GradientBoosting': (
        GradientBoostingClassifier(),
        {'n_estimators': [50, 100, 200],
         'max_depth': [3, 5, 7],
         'learning_rate': [0.05, 0.1, 0.2]}
    ),
    'XGBoost': (
        XGBClassifier(eval_metric='logloss'),
        {'n_estimators': [50, 100, 200],
         'max_depth': [3, 5, 7],
         'learning_rate': [0.05, 0.1, 0.2]}
    ),
}

best_score = 0
best_name = ''
best_estimator = None

for name, (clf, params) in classifiers_grid.items():
    grid = GridSearchCV(clf, param_grid=params, cv=4, scoring='accuracy', n_jobs=-1)
    grid.fit(X_train, y_train)
    
    val_score = grid.score(X_val, y_val)
    print(f"{name}:")
    print(f"  best params : {grid.best_params_}")
    print(f"  CV accuracy : {grid.best_score_:.4f}")
    print(f"  val accuracy: {val_score:.4f}")
    
    if val_score > best_score:
        best_score = val_score
        best_name = name
        best_estimator = grid.best_estimator_

print(f"\nBest clf: {best_name} (val accuracy={best_score:.4f})")

best_estimator.fit(X, y)
predictions = best_estimator.predict(test[features])
# Out:
# LogisticRegression:
#   best params : {'C': 1}
#   CV accuracy : 0.8009
#   val accuracy: 0.8072
# DecisionTree:
#   best params : {'max_depth': 3, 'min_samples_split': 2}
#   CV accuracy : 0.8204
#   val accuracy: 0.8027
# RandomForest:
#   best params : {'max_depth': 7, 'min_samples_split': 5, 'n_estimators': 50}
#   CV accuracy : 0.8353
#   val accuracy: 0.8296
# GradientBoosting:
#   best params : {'learning_rate': 0.05, 'max_depth': 3, 'n_estimators': 200}
#   CV accuracy : 0.8249
#   val accuracy: 0.8027
# XGBoost:
#   best params : {'learning_rate': 0.05, 'max_depth': 3, 'n_estimators': 100}
#   CV accuracy : 0.8323
#   val accuracy: 0.8206
#
# Best clf: RandomForest (val accuracy=0.8296)

# %%
output = pd.DataFrame({
    'PassengerId': test['PassengerId'],
    'Survived': predictions
})
output.to_csv('submission.csv', index=False)
